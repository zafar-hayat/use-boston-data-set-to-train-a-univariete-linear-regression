# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("train.csv")
a
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
b=pd.read_csv("test.csv")
pd.options.display.max_columns=81
b=b.fillna(1)
b
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave     1      Reg
# 1     1462          20       RL         81.0    14267   Pave     1      IR1
# 2     1463          60       RL         74.0    13830   Pave     1      IR1
# 3     1464          60       RL         78.0     9978   Pave     1      IR1
# 4     1465         120       RL         43.0     5005   Pave     1      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave     1      Reg
# 1455  2916         160       RM         21.0     1894   Pave     1      Reg
# 1456  2917          20       RL        160.0    20000   Pave     1      Reg
# 1457  2918          85       RL         62.0    10441   Pave     1      Reg
# 1458  2919          60       RL         74.0     9627   Pave     1      Reg
#
# ...

# %%
b
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave     1      Reg
# 1     1462          20       RL         81.0    14267   Pave     1      IR1
# 2     1463          60       RL         74.0    13830   Pave     1      IR1
# 3     1464          60       RL         78.0     9978   Pave     1      IR1
# 4     1465         120       RL         43.0     5005   Pave     1      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave     1      Reg
# 1455  2916         160       RM         21.0     1894   Pave     1      Reg
# 1456  2917          20       RL        160.0    20000   Pave     1      Reg
# 1457  2918          85       RL         62.0    10441   Pave     1      Reg
# 1458  2919          60       RL         74.0     9627   Pave     1      Reg
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
a.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
a.mean()
# Out:
# Id                  730.500000
# MSSubClass           56.897260
# LotFrontage          70.049958
# LotArea           10516.828082
# OverallQual           6.099315
# OverallCond           5.575342
# YearBuilt          1971.267808
# YearRemodAdd       1984.865753
# MasVnrArea          103.685262
# BsmtFinSF1          443.639726
# BsmtFinSF2           46.549315
# BsmtUnfSF           567.240411
# TotalBsmtSF        1057.429452
# 1stFlrSF           1162.626712
# 2ndFlrSF            346.992466
# LowQualFinSF          5.844521
# GrLivArea          1515.463699
# BsmtFullBath          0.425342
# BsmtHalfBath          0.057534
# FullBath              1.565068
# HalfBath              0.382877
# BedroomAbvGr          2.866438
# KitchenAbvGr          1.046575
# TotRmsAbvGrd          6.517808
# Fireplaces            0.613014
# GarageYrBlt        1978.506164
# GarageCars            1.767123
# GarageArea          472.980137
# WoodDeckSF           94.244521
# OpenPorchSF          46.660274
# ...

# %%
a.max()
# Out:
# Id                  1460
# MSSubClass           190
# MSZoning              RM
# LotFrontage        313.0
# LotArea           215245
#                   ...
# MoSold                12
# YrSold              2010
# SaleType              WD
# SaleCondition    Partial
# SalePrice         755000
# Length: 65, dtype: object

# %%
a.min()
# Out:
# Id                     1
# MSSubClass            20
# MSZoning         C (all)
# LotFrontage         21.0
# LotArea             1300
#                   ...
# MoSold                 1
# YrSold              2006
# SaleType             COD
# SaleCondition    Abnorml
# SalePrice          34900
# Length: 65, dtype: object

# %%
a.dropna()
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %%
a.isnull()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1455  False       False     False        False    False   False   True
# 1456  False       False     False        False    False   False   True
# 1457  False       False     False        False    False   False   True
# 1458  False       False     False        False    False   False   True
# 1459  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# ...

# %%
a.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
a.columns.value_counts()
# Out:
# BsmtHalfBath     1
# GarageQual       1
# EnclosedPorch    1
# FireplaceQu      1
# Functional       1
#                 ..
# GarageYrBlt      1
# GarageArea       1
# Id               1
# GarageCars       1
# Electrical       1
# Length: 81, dtype: int64

# %%
a.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
a=a.fillna(1)
a
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave     1      Reg
# 1        2          20       RL         80.0     9600   Pave     1      Reg
# 2        3          60       RL         68.0    11250   Pave     1      IR1
# 3        4          70       RL         60.0     9550   Pave     1      IR1
# 4        5          60       RL         84.0    14260   Pave     1      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave     1      Reg
# 1456  1457          20       RL         85.0    13175   Pave     1      Reg
# 1457  1458          70       RL         66.0     9042   Pave     1      Reg
# 1458  1459          20       RL         68.0     9717   Pave     1      Reg
# 1459  1460          20       RL         75.0     9937   Pave     1      Reg
#
# ...

# %%
a.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
(a.corr()>0.4).sum()
# Out:
# Id                1
# MSSubClass        1
# LotFrontage       1
# LotArea           1
# OverallQual      12
# OverallCond       1
# YearBuilt         7
# YearRemodAdd      6
# MasVnrArea        3
# BsmtFinSF1        4
# BsmtFinSF2        1
# BsmtUnfSF         2
# TotalBsmtSF       9
# 1stFlrSF         10
# 2ndFlrSF          6
# LowQualFinSF      1
# GrLivArea        13
# BsmtFullBath      2
# BsmtHalfBath      1
# FullBath         10
# HalfBath          3
# BedroomAbvGr      4
# KitchenAbvGr      1
# TotRmsAbvGrd      8
# Fireplaces        4
# GarageYrBlt       3
# GarageCars       11
# GarageArea       10
# WoodDeckSF        1
# OpenPorchSF       1
# EnclosedPorch     1
# 3SsnPorch         1
# ScreenPorch       1
# PoolArea          1
# MiscVal           1
# MoSold            1
# YrSold            1
# SalePrice        13
# dtype: int64

# %% [markdown]
# # 1. Train a univariate linear regression by selecting the best feature from the dataset and predict "test.csv".

# %%
x=a[["GrLivArea"]]
x
# Out:
#       GrLivArea
# 0          1710
# 1          1262
# 2          1786
# 3          1717
# 4          2198
# ...         ...
# 1455       1647
# 1456       2073
# 1457       2340
# 1458       1078
# 1459       1256
#
# [1460 rows x 1 columns]

# %%
y=a[["SalePrice"]]
y
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 1 columns]

# %%
x.shape
# Out:
# (1460, 1)

# %%
y.shape
# Out:
# (1460, 1)

# %%
x.isnull().sum()
# Out:
# GrLivArea    0
# dtype: int64

# %%
y.isnull().sum()
# Out:
# SalePrice    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.1,shuffle=True,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear=LinearRegression()

# %%
linear.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# ### select from test_csv file

# %%
testing=b[["GrLivArea"]]
testing
# Out:
#       GrLivArea
# 0           896
# 1          1329
# 2          1629
# 3          1604
# 4          1280
# ...         ...
# 1454       1092
# 1455       1092
# 1456       1224
# 1457        970
# 1458       2000
#
# [1459 rows x 1 columns]

# %%
linear.predict(testing)
# Out:
# array([[115500.87453833],
#        [160327.56980551],
#        [191385.32634166],
#        ...,
#        [149457.35501786],
#        [123161.78781725],
#        [229793.41859137]])

# %% [markdown]
# # Univerient Regreesion

# %%
linear.score(xtest,ytest)
# Out:
# 0.6067608955794143

# %%
w=[linear.score(xtest,ytest)]
w=pd.DataFrame(w,columns=["Univerient_score"])
w
# Out:
#    Univerient_score
# 0          0.606761

# %%
plt.scatter(xtrain,ytrain,)
plt.plot(testing,linear.predict(testing),color="red")

# %% [markdown]
# # 2. Train a multivariate linear regression by selecting 5 most important from the dataset and predict "test.csv"

# %%
x1=a[["OverallQual","1stFlrSF","GrLivArea","FullBath","GarageCars","GarageArea"]]
x1
# Out:
#       OverallQual  1stFlrSF  GrLivArea  FullBath  GarageCars  GarageArea
# 0               7       856       1710         2           2         548
# 1               6      1262       1262         2           2         460
# 2               7       920       1786         2           2         608
# 3               7       961       1717         1           3         642
# 4               8      1145       2198         2           3         836
# ...           ...       ...        ...       ...         ...         ...
# 1455            6       953       1647         2           2         460
# 1456            6      2073       2073         2           2         500
# 1457            7      1188       2340         2           1         252
# 1458            5      1078       1078         1           1         240
# 1459            5      1256       1256         1           1         276
#
# [1460 rows x 6 columns]

# %%
y1=a[["SalePrice"]]
y1
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 1 columns]

# %% [markdown]
# ### Select test_csv file

# %%
testing1=b[["OverallQual","1stFlrSF","GrLivArea","FullBath","GarageCars","GarageArea"]]
testing1
# Out:
#       OverallQual  1stFlrSF  GrLivArea  FullBath  GarageCars  GarageArea
# 0               5       896        896         1         1.0       730.0
# 1               6      1329       1329         1         1.0       312.0
# 2               5       928       1629         2         2.0       482.0
# 3               6       926       1604         2         2.0       470.0
# 4               8      1280       1280         2         2.0       506.0
# ...           ...       ...        ...       ...         ...         ...
# 1454            4       546       1092         1         0.0         0.0
# 1455            4       546       1092         1         1.0       286.0
# 1456            5      1224       1224         1         2.0       576.0
# 1457            5       970        970         1         0.0         0.0
# 1458            7       996       2000         2         3.0       650.0
#
# [1459 rows x 6 columns]

# %%
x1train,x1test,y1train,y1test=train_test_split(x1,y1,test_size=0.1,shuffle=True,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear=LinearRegression()

# %%
linear.fit(x1train,y1train)
# Out:
# LinearRegression()

# %%
linear.predict(testing1)
# Out:
# array([[116049.62229003],
#        [161197.26644767],
#        [153476.39724885],
#        ...,
#        [148241.37661246],
#        [ 90342.12085445],
#        [237876.65842398]])

# %% [markdown]
# # Multiverient Regression

# %%
linear.score(x1test,y1test)
# Out:
# 0.8185834847778619

# %%
plt.scatter(x1train["OverallQual"],y1train,color="blue")
plt.scatter(x1train["1stFlrSF"],y1train,color="green")
plt.scatter(x1train["GrLivArea"],y1train,color="red")
plt.scatter(x1train["FullBath"],y1train,color="pink")
plt.scatter(x1train["GarageCars"],y1train,color="brown")
plt.scatter(x1train["GarageArea"],y1train,color="black")
plt.plot(testing1,linear.predict(testing1))

# %%
w["Multiverient_Score"]=[linear.score(x1test,y1test)]
w
# Out:
#    Univerient_score  Multiverient_Score
# 0          0.606761            0.818583

# %% [markdown]
# # 3. Transform features using "Standard Scaler" function and train polynomial regression to predict "test.csv".

# %%
from sklearn.preprocessing import StandardScaler

# %%
x2=a[["OverallQual","1stFlrSF","GrLivArea","FullBath","GarageCars","GarageArea"]]
x2
# Out:
#       OverallQual  1stFlrSF  GrLivArea  FullBath  GarageCars  GarageArea
# 0               7       856       1710         2           2         548
# 1               6      1262       1262         2           2         460
# 2               7       920       1786         2           2         608
# 3               7       961       1717         1           3         642
# 4               8      1145       2198         2           3         836
# ...           ...       ...        ...       ...         ...         ...
# 1455            6       953       1647         2           2         460
# 1456            6      2073       2073         2           2         500
# 1457            7      1188       2340         2           1         252
# 1458            5      1078       1078         1           1         240
# 1459            5      1256       1256         1           1         276
#
# [1460 rows x 6 columns]

# %%
scaler=StandardScaler()

# %%
x2=scaler.fit_transform(x2)
x2
# Out:
# array([[ 0.65147924, -0.79343379,  0.37033344,  0.78974052,  0.31172464,
#          0.35100032],
#        [-0.07183611,  0.25714043, -0.48251191,  0.78974052,  0.31172464,
#         -0.06073101],
#        [ 0.65147924, -0.62782603,  0.51501256,  0.78974052,  0.31172464,
#          0.63172623],
#        ...,
#        [ 0.65147924,  0.06565646,  1.56964722,  0.78974052, -1.02685765,
#         -1.03391416],
#        [-0.79515147, -0.21898188, -0.83278768, -1.02604084, -1.02685765,
#         -1.09005935],
#        [-0.79515147,  0.2416147 , -0.49393395, -1.02604084, -1.02685765,
#         -0.9216238 ]])

# %%
y2=a[["SalePrice"]]
y2
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x2train,x2test,y2train,y2test=train_test_split(x2,y2,test_size=0.2,shuffle=True,random_state=150)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures()

# %%
x2train=poly.fit_transform(x2train)
x2test=poly.fit_transform(x2test)

# %%
poly.fit(x2train,y2train)
# Out:
# PolynomialFeatures()

# %%
from sklearn.linear_model import LinearRegression

# %%
polys=LinearRegression()

# %%
polys.fit(x2train,y2train)
# Out:
# LinearRegression()

# %%
testing3=b[["OverallQual","1stFlrSF","GrLivArea","FullBath","GarageCars","GarageArea"]]
testing3=scaler.fit_transform(testing3)
testing3=poly.fit_transform(testing3)
testing3
# Out:
# array([[ 1.00000000e+00, -7.51101246e-01, -6.54561319e-01, ...,
#          9.74180134e-01, -1.17011118e+00,  1.40544868e+00],
#        [ 1.00000000e+00, -5.48771558e-02,  4.33298172e-01, ...,
#          9.74180134e-01,  7.28929582e-01,  5.45421033e-01],
#        [ 1.00000000e+00, -7.51101246e-01, -5.74165236e-01, ...,
#          9.13240440e-02,  1.32904113e-02,  1.93415692e-03],
#        ...,
#        [ 1.00000000e+00, -7.51101246e-01,  1.69498526e-01, ...,
#          9.13240440e-02,  1.44045558e-01,  2.27203284e-01],
#        [ 1.00000000e+00, -7.51101246e-01, -4.68645378e-01, ...,
#          5.18113180e+00,  4.94996830e+00,  4.72911848e+00],
#        [ 1.00000000e+00,  6.41346934e-01, -4.03323561e-01, ...,
#          2.53256353e+00,  1.30061933e+00,  6.67944007e-01]])

# %% [markdown]
# ### Select From test_scv file

# %%
polys.predict(testing3)
# Out:
# array([[130887.67498039],
#        [161285.1608932 ],
#        [156972.08453589],
#        ...,
#        [149597.70814888],
#        [108314.90915355],
#        [247353.05911283]])

# %% [markdown]
# # Polynomial_score

# %%
polys.score(x2test,y2test)
# Out:
# 0.8323195304202375

# %%
plt.scatter(x1train["OverallQual"],y1train,color="blue")
plt.scatter(x1train["1stFlrSF"],y1train,color="green")
plt.scatter(x1train["GrLivArea"],y1train,color="red")
plt.scatter(x1train["FullBath"],y1train,color="pink")
plt.scatter(x1train["GarageCars"],y1train,color="brown")
plt.scatter(x1train["GarageArea"],y1train,color="black")
plt.plot(testing3,linear.predict(testing3))

# %%
w["Polynomial_with_scaler_Score"]=[polys.score(x2test,y2test)]
w
# Out:
#    Univerient_score  Multiverient_Score  Polynomial_with_scaler_Score
# 0          0.606761            0.818583                       0.83232
